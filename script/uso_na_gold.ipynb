# %%
import duckdb

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute("SELECT * FROM produtos").fetchdf()
df.head(10)
# Out:
#      id nm_produto id_categoria  id_fornecedor  vl_preco
# 0  1002    MARTELO         BT50            100    1500.0
# 1  1001   PARAFUSO         BT10            100     100.0
# 2  1003      PREGO         BT10            100     150.0
# 3  1005    MACHADO         BT50            100    1500.0
# 4  1004      SERRA         BT50            100     100.0

# %%
df2 = df.drop(columns=['id_categoria', 'id_fornecedor'])
df2.head(10)
# Out:
#      id nm_produto  vl_preco
# 0  1002    MARTELO    1500.0
# 1  1001   PARAFUSO     100.0
# 2  1003      PREGO     150.0
# 3  1005    MACHADO    1500.0
# 4  1004      SERRA     100.0

# %%
con.execute("""
                CREATE TABLE IF NOT EXISTS dim_produtos (
                    id_produto BIGINT,
                    nm_produto TEXT,
                    vl_preco FLOAT)
                """)

# %%
con.execute("DROP TABLE IF EXISTS dim_produtos").fetchdf()
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
df_dim = con.execute("SELECT * FROM dim_produtos").fetchdf()
df_dim.head(10)
# Out:
# Empty DataFrame
# Columns: [id_produto, nm_produto, vl_preco]
# Index: []

# %%
con.execute("INSERT INTO dim_produtos SELECT * FROM df2")
df_dim = con.execute("SELECT * FROM dim_produtos").fetchdf()
df_dim.head(10)
# Out:
#    id_produto nm_produto  vl_preco
# 0        1002    MARTELO    1500.0
# 1        1001   PARAFUSO     100.0
# 2        1003      PREGO     150.0
# 3        1005    MACHADO    1500.0
# 4        1004      SERRA     100.0

# %%
con.close()
